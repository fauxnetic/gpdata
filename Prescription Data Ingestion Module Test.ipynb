# %%
import pxdatautil as px

# %%
test = px.get_prescription_data_filepaths(2015, 1, 2015, 2)
test
# Out:
# ['./full_data/2015_01_January/T201501PDPI BNFT.CSV',
#  './full_data/2015_02_February/T201502PDPI BNFT.CSV']

# %%
test_addr_data = px.load_address_data(2014, 10)
test_addr_data
# Out:
#      Year-Month PracticeCode                              PracticeName  \
# 0    2014-10-01       A81001  THE DENSHAM SURGERY
# 1    2014-10-01       A81002  QUEENS PARK MEDICAL CENTRE
# 2    2014-10-01       A81003  THE HEALTH CENTRE
# 3    2014-10-01       A81004  WOODLANDS ROAD SURGERY
# 4    2014-10-01       A81005  SPRINGWOOD SURGERY
# 5    2014-10-01       A81006  TENNANT STREET MEDICAL PRACTICE
# 6    2014-10-01       A81007  BANKHOUSE SURGERY
# 7    2014-10-01       A81008  ALBERT HOUSE CLINIC
# 8    2014-10-01       A81009  VILLAGE MEDICAL CENTRE
# 9    2014-10-01       A81011  CHADWICK PRACTICE
# 10   2014-10-01       A81012  WESTBOURNE MEDICAL CENTRE
# 11   2014-10-01       A81013  BROTTON SURGERY
# 12   2014-10-01       A81014  QUEENSTREE PRACTICE
# 13   2014-10-01       A81015  LAGAN SURGERY
# 14   2014-10-01       A81016  PARK SURGERY
# 15   2014-10-01       A81017  WOODBRIDGE PRACTICE
# 16   2014-10-01       A81018  BENTLEY MEDICAL PRACTICE
# ...

# %%
test_chems_data = px.load_chems_data(2011, 7)
test_chems_data
# Out:
#        ChemCode                                           ChemName
# 0     0101010A0  Alexitol Sodium                               ...
# 1     0101010B0  Almasilate                                    ...
# 2     0101010C0  Aluminium Hydroxide                           ...
# 3     0101010D0  Aluminium Hydroxide With Magnesium            ...
# 4     0101010E0  Hydrotalcite                                  ...
# 5     0101010F0  Magnesium Carbonate                           ...
# 6     0101010G0  Co-Magaldrox(Magnesium/Aluminium Hydrox)      ...
# 7     0101010I0  Magnesium Oxide                               ...
# 8     0101010J0  Magnesium Trisilicate                         ...
# 9     0101010L0  Aluminium & Magnesium & Act Simeticone        ...
# 10    0101010M0  Magaldrate                                    ...
# 11    0101010N0  Aluminium & Magnesium & Oxetacaine            ...
# 12    0101010P0  Co-Simalcite (Simeticone/Hydrotalcite)        ...
# ...

# %%
test_px_data = px.load_prescription_data(2012, 4)
test_px_data
# Out:
#          SHA  PCT PracticeCode          BNFCode  \
# 0        Q30  5D7       A86001  20030100167
# 1        Q30  5D7       A86001  20030400290
# 2        Q30  5D7       A86003  0101010G0AAABAB
# 3        Q30  5D7       A86003  0101010R0BCAAAB
# 4        Q30  5D7       A86003  0101021B0AAAHAH
# 5        Q30  5D7       A86003  0101021B0AAALAL
# 6        Q30  5D7       A86003  0101021B0BCAAAC
# 7        Q30  5D7       A86003  0101021B0BEADAJ
# 8        Q30  5D7       A86003  0101021B0BEAIAL
# 9        Q30  5D7       A86003  0101021B0BEAKAQ
# 10       Q30  5D7       A86003  0101021B0BEAQAP
# 11       Q30  5D7       A86003  0101021B0BFAAAF
# 12       Q30  5D7       A86003  0101021B0BIAAAH
# 13       Q30  5D7       A86003  0101021B0BIABAH
# 14       Q30  5D7       A86003  0102000A0AAAAAA
# 15       Q30  5D7       A86003  0102000J0AAABAB
# 16       Q30  5D7       A86003  0102000N0AAABAB
# 17       Q30  5D7       A86003  0102000P0AAABAB
# 18       Q30  5D7       A86003  0102000P0AAADAD
# ...

# %%
px.check_data(2010, 8, 2015, 2)
# Out:
# WARNING: File not found - ./full_data/2012_03_March/T201203ADDR BNFT.CSV
# WARNING: File not found - ./full_data/2012_06_June/T201206ADDR BNFT.CSV
# WARNING: File not found - ./full_data/2012_06_June/T201206CHEM SUBS.CSV
# WARNING: File not found - ./full_data/2012_06_June/T201206PDPI BNFT.CSV
# WARNING: File not found - ./full_data/2013_03_March/T201303ADDR BNFT.CSV
# WARNING: File not found - ./full_data/2013_03_March/T201303CHEM SUBS.CSV
# WARNING: File not found - ./full_data/2013_03_March/T201303PDPI BNFT.CSV
# WARNING: File not found - ./full_data/2013_06_June/T201306ADDR BNFT.CSV
# WARNING: File not found - ./full_data/2013_06_June/T201306CHEM SUBS.CSV
# WARNING: File not found - ./full_data/2013_06_June/T201306PDPI BNFT.CSV
# WARNING: File not found - ./full_data/2013_09_September/T201309ADDR BNFT.CSV
# WARNING: File not found - ./full_data/2013_09_September/T201309CHEM SUBS.CSV
# WARNING: File not found - ./full_data/2013_09_September/T201309PDPI BNFT.CSV
# ...

# %% [markdown]
# ## Allowed the discovery of several file issues:
# - /2012_03_March/T201203ADDR BNFT.CSv (lowercase 'v')
# - /2012_06_Jun/* (Shortened form of June in dir)
# - /2013_03_March/* (3x lowercase .csv)
# - /2013_06_June/* (3x lowercase .csv)
# - /2013_9_September/* (no leading zero)
# - /2014_07_JULY/* (CAPS on month)
# - /2014_12_December/... (2x files MISSING)
